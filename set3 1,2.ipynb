# %%
#q1
from tkinter import *
window=Tk()
window.title("SURVEY RA1910....")
window.geometry('500x700')
window.config(bg='white')
radio = IntVar()
radio1 = IntVar()
f=Label(text='Feedback',font=("bold",19),width=10).place(x=165,y=0)
m=Label(window,text="Name of the phone",font=("bold",12),width=14).place(x=10,y=50)
r=Label(window,text="Model Name",font=("bold",12),width=10).place(x=10,y=140)
q=Label(window,text="How was the OS:",font=("bold",10),width=14).place(x=10,y=230)
o=Label(window,text="Battery Backup:",font=("bold",10),width=12).place(x=10,y=310)
n=Label(window,text="Any Suggestions",font=("bold",10),width=13).place(x=10,y=390)
rad1=Radiobutton(window,text="One plus",variable=radio,value=1).place(x=40,y=90)
rad2=Radiobutton(window,text="Iphone",variable=radio,value=2).place(x=150,y=90)
rad3=Radiobutton(window,text="Samsung",variable=radio,value=3).place(x=250,y=90)
rad4=Radiobutton(window,text="Redmi",variable=radio,value=4).place(x=350,y=90)
rad5=Radiobutton(window,text="oneplus 7T",variable=radio1,value=1).place(x=40,y=180)
rad6=Radiobutton(window,text="Iphone 11",variable=radio1,value=2).place(x=150,y=180)
rad7=Radiobutton(window,text="S20 ultron",variable=radio1,value=3).place(x=250,y=180)
rad8=Radiobutton(window,text="Note 10",variable=radio1,value=4).place(x=350,y=180)
entry=Entry(window,width=70).place(x=12,y=270)
entry1=Entry(window,width=70).place(x=12,y=340)
entry2=Entry(window,width=70).place(x=12,y=420)
Button(window,text="Submit",font=("bold",10)).place(x=160,y=480)
Button(window,text="Reset",font=("bold",10)).place(x=280,y=480)
window.mainloop()

# %%
#q2
import tkinter as tk
from tkinter import messagebox

root = tk.Tk()
root.geometry("500x500")

d1 = ["Department is CSE", "Strength: 150 Students", "Topper: Pavan Sai.K"]
d2 = ["Department is ECE", "Strength: 90 Students", "Topper: Prashanth"]
d3 = ["Department is Mechanical", "Strength: 95 Students", "Topper: Teja"]
d4 = ["Department is Chemical", "Strength: 15 Students", "Topper: Dinesh"]
d5 = ["Department is Aeronautics", "Strength: 70 Students", "Topper: Vamsi"]
d6 = ["Department is Law", "Strength: 50 Students", "Topper: Naveen"]
d7 = ["Department is MBA", "Strength: 68 Students", "Topper: Balu"]
d8 = ["Department is Bio Chemistry", "Strength: 25 Students", "Topper: Barghav"]
d9 = ["Department is Dental", "Strength: 80 Students", "Topper: Pawan Kalyan"]

x = 0

dep_var = tk.StringVar()
information = tk.StringVar()

def submit():
    department=dep_var.get()
    if department == "CSE":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d1)
    elif department == "ECE":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d2)
    elif department == "Mechanical":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d3)
    elif department == "Chemical":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d4)
    elif department == "Aeronautical":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d5)
    elif department == "Law":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d6)
    elif department == "MBA":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d7)
    elif department == "Bio Chemistry":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d8)
    elif department == "Dental":
            info = tk.Label(root ,textvariable = information,font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
            information.set(d9)
    else:
            info = tk.Label(root ,text = "Enter Valid Department",font=('calibre',10, 'bold'))
            info.place(x=50,y=250)
                         

def setFlag():
    user_name = tk.Label(root, text = "Welcome").place(x = 50,y = 100) 
    x = 1
    
    if x==1:
        dep_label = tk.Label(root, text = 'Department:', font=('calibre',10, 'bold')).place(x=50,y=150)
        dep_entry = tk.Entry(root,textvariable = dep_var)
        dep_entry.place(x=150,y=150)
        sub_btn=tk.Button(root,text = 'Submit', command = submit).place(x=50,y=200)
            
    
b = tk.Button(root, text='Start',command=setFlag)
b.place(x=50,y=50)


root.mainloop()
